# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv("medical_insurance.csv")

# %%
dados.head()
# Out:
#    age     sex        bmi  children smoker     region       charges
# 0   56  female  29.774374         2    yes  southwest  31109.889763
# 1   46    male  25.857395         1     no  northeast  26650.702647
# 2   32    male  23.014840         0     no  southwest  21459.037990
# 3   19  female  27.900000         0    yes  southwest  16884.924000
# 4   18    male  33.770000         1     no  southeast   1725.552300

# %%
dados.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 4108   50    male  30.97         3     no  northwest  10600.5483
# 4109   18  female  31.92         0     no  northeast   2205.9808
# 4110   18  female  36.85         0     no  southeast   1629.8335
# 4111   21  female  25.80         0     no  southwest   2007.9450
# 4112   61  female  29.07         0    yes  northwest  29141.3603

# %%
dados.shape
# Out:
# (4113, 7)

# %%
dados.describe()
# Out:
#                age          bmi     children       charges
# count  4113.000000  4113.000000  4113.000000   4113.000000
# mean     39.145393    30.685731     1.099441  13273.902783
# std      14.067748     6.117991     1.211401  12137.945368
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4719.524050
# 50%      39.000000    30.400000     1.000000   9377.904700
# 75%      51.000000    34.770000     2.000000  16586.497710
# max      64.000000    53.130000     5.000000  63770.428010

# %%
dados.groupby("sex").describe()
# Out:
#            age                                                         bmi  \
#          count       mean        std   min   25%   50%   75%   max   count
# sex
# female  2029.0  39.496796  14.078311  18.0  27.0  40.0  52.0  64.0  2029.0
# male    2084.0  38.803263  14.052390  18.0  26.0  39.0  51.0  64.0  2084.0
#
#                    ... children      charges                              \
#              mean  ...      75%  max   count          mean           std
# sex                ...
# female  30.415640  ...      2.0  5.0  2029.0  12523.008164  11077.667335
# male    30.948693  ...      2.0  5.0  2084.0  14004.980126  13049.197491
#
#
#               min       25%         50%         75%          max
# sex
# female  1607.5101  4830.630  9411.00500  14449.8544  63770.42801
# male    1121.8739  4536.259  9369.61575  19199.9440  62592.87309
#
# [2 rows x 32 columns]

# %%
dados.groupby("smoker").describe()
# Out:
#            age                                                         bmi  \
#          count       mean        std   min   25%   50%   75%   max   count
# smoker
# no      3274.0  39.310935  14.099397  18.0  26.0  39.5  52.0  64.0  3274.0
# yes      839.0  38.499404  13.933089  18.0  27.0  38.0  49.0  64.0   839.0
#
#                    ... children      charges                              \
#              mean  ...      75%  max   count          mean           std
# smoker             ...
# no      30.657420  ...      2.0  5.0  3274.0   8432.754401   6018.497670
# yes     30.796209  ...      2.0  5.0   839.0  32165.344742  11514.466954
#
#
#                min         25%          50%           75%          max
# smoker
# no       1121.8739   3972.9247   7345.08400  11361.231475  36910.60803
# yes     12829.4551  20984.0936  34617.84065  41065.691575  63770.42801
#
# [2 rows x 32 columns]

# %%
dados.groupby("region").describe()
# Out:
#               age                                                         bmi  \
#             count       mean        std   min   25%   50%   75%   max   count
# region
# northeast   983.0  39.258393  14.014117  18.0  27.0  39.0  51.0  64.0   983.0
# northwest   989.0  39.119312  14.072323  19.0  26.0  39.0  51.0  64.0   989.0
# southeast  1130.0  38.819469  14.232200  18.0  26.0  39.0  51.0  64.0  1130.0
# southwest  1011.0  39.425321  13.943277  19.0  27.0  39.0  51.0  64.0  1011.0
#
#                       ... children      charges                              \
#                 mean  ...      75%  max   count          mean           std
# region                ...
# northeast  29.159606  ...      2.0  5.0   983.0  13466.373208  11288.973915
# northwest  29.164520  ...      2.0  5.0   989.0  12448.159618  11015.656152
# southeast  33.439221  ...      2.0  5.0  1130.0  14744.472112  14078.584329
# southwest  30.580108  ...      2.0  5.0  1011.0  12250.874319  11466.546474
#
#
# ...

# %%
dados.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
plt.scatter(dados['age'], dados['charges'])
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Relação entre Idade e Preço do plano de saúde')
plt.show()

# %%
plt.scatter(dados['sex'], dados['charges'])
plt.xlabel('Sex')
plt.ylabel('Charges')
plt.title('Relação entre Sexo e Preço do plano de saúde')
plt.show()

# %%
plt.scatter(dados['smoker'], dados['charges'])
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.title('Relação entre Fumante e Preço do plano de saúde')
plt.show()

# %%
plt.scatter(dados['bmi'], dados['charges'])
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.title('Relação entre IMC e Preço do plano de saúde')
plt.show()

# %%
plt.scatter(dados['children'], dados['charges'])
plt.xlabel('Children')
plt.ylabel('Charges')
plt.title('Relação entre Filhos e Preço do plano de saúde')
plt.show()

# %%
plt.scatter(dados['region'], dados['charges'])
plt.xlabel('Region')
plt.ylabel('Charges')
plt.title('Relação entre Região e Preço do plano de saúde')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
dados["sex"] = labelencoder.fit_transform(dados["sex"])
dados["smoker"] = labelencoder.fit_transform(dados["smoker"])
dados["region"] = labelencoder.fit_transform(dados["region"])

dados.head()
# Out:
#    age  sex        bmi  children  smoker  region       charges
# 0   56    0  29.774374         2       1       3  31109.889763
# 1   46    1  25.857395         1       0       0  26650.702647
# 2   32    1  23.014840         0       0       3  21459.037990
# 3   19    0  27.900000         0       1       3  16884.924000
# 4   18    1  33.770000         1       0       2   1725.552300

# %%
correlation_matrix = dados.corr().round(2)

fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(data=correlation_matrix, annot=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# * Análise dos dados
# 	* 4113 registros
# 	* 2029 mulheres
# 	* 2084 homens
# 	* 3274 não fumantes
# 	* 839 fumantes
# 	* mais dados do sul do que do norte
# 	* não tem dados nulos
# 	* relações
# 		* idade X preço:
# 			* preço aumenta com a idade
# 		* sexo X preço:
# 			* sem mudanças expressivas
# 		* fumante X preço:
# 			* preço aumenta para fumantes
# 		* IMC X preço:
# 			* preço menor para IMC baixo
# 			* outliers esquisitos (outros fatores?)
# 		* filhos X preço:
# 			* preço menor para pessoas com menos filhos
# 		* região X preço:
# 			* sem mudanças expressivas
# 	* Aplicado LabelEncoder nas colunas de texto (sex, smoker, region)
# 	* Análise de correlação com gráfico do `seaborn`
